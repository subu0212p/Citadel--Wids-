# %%
# !pip install gymnasium
from trading_env import TradingEnv

env = TradingEnv(max_steps=10)

obs, info = env.reset()
print("Initial obs:", obs)

done = False
while not done:
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    print("Obs:", obs, "Reward:", reward, "Info:", info)
    done = terminated or truncated
# Out:
# Requirement already satisfied: gymnasium in d:\new\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: numpy>=1.21.0 in d:\new\anaconda3\lib\site-packages (from gymnasium) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in d:\new\anaconda3\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in d:\new\anaconda3\lib\site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in d:\new\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Initial obs: [0.5 0.  1. ]
# Obs: [ 0.51038533 -0.1         1.0510385 ] Reward: 0.0 Info: {'portfolio_value': np.float64(1.0), 'step': 1}
# Obs: [ 0.5381814 -0.1        1.0510385] Reward: 0.0 Info: {'portfolio_value': np.float64(0.9972203938810271), 'step': 2}
# Obs: [0.5484525 0.        0.9961933] Reward: 0.0 Info: {'portfolio_value': np.float64(0.9961932868165785), 'step': 3}
# Obs: [0.5371328 0.        0.9961933] Reward: 0.0 Info: {'portfolio_value': np.float64(0.9961932868165785), 'step': 4}
# Obs: [0.5284436 0.        0.9961933] Reward: 0.0 Info: {'portfolio_value': np.float64(0.9961932868165785), 'step': 5}
# Obs: [ 0.5370159 -0.1        1.0498949] Reward: 0.0 Info: {'portfolio_value': np.float64(0.9961932868165786), 'step': 6}
# Obs: [0.5457544 0.        0.9953194] Reward: 0.0 Info: {'portfolio_value': np.float64(0.995319443269801), 'step': 7}
# Obs: [0.5432972 0.        0.9953194] Reward: 0.0 Info: {'portfolio_value': np.float64(0.995319443269801), 'step': 8}
# Obs: [0.54354846 0.         0.9953194 ] Reward: 0.0 Info: {'portfolio_value': np.float64(0.995319443269801), 'step': 9}
# Obs: [ 0.55024654 -0.1         1.0503441 ] Reward: 0.0 Info: {'portfolio_value': np.float64(0.995319443269801), 'step': 10}
