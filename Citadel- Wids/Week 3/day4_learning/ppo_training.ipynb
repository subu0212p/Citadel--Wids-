# %%
pip install stable-baselines3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from stable_baselines3 import PPO

# %%
import os
print(os.getcwd())
# Out:
# C:\Users\subod\OneDrive\Documents\Desktop\Citadel- Wids\Week 3\day4_learning

# %%
import sys
import os

sys.path.insert(0, os.path.abspath(".."))

# %%
import numpy as np
from stable_baselines3 import PPO
from stable_baselines3.common.env_checker import check_env

from day2_environment.trading_env import TradingEnv

# %%
env = TradingEnv(max_steps=100)

check_env(env, warn=True)
print("Environment check passed")
# Out:
# Environment check passed

# %%
model = PPO(
    policy="MlpPolicy",
    env=env,
    verbose=1
)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
model.learn(total_timesteps=10_000)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 100      |
# |    ep_rew_mean     | -0.335   |
# | time/              |          |
# |    fps             | 878      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 100         |
# |    ep_rew_mean          | -0.475      |
# | time/                   |             |
# |    fps                  | 533         |
# |    iterations           | 2           |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.013816675 |
# |    clip_fraction        | 0.355       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# ...

# %%
obs, _ = env.reset()

for _ in range(20):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)
    print(f"Action: {action}, Reward: {reward:.5f}, Inventory: {info['inventory']:.2f}")

    if terminated or truncated:
        obs, _ = env.reset()
# Out:
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00
# Action: 0, Reward: 0.00000, Inventory: 0.00

# %% [markdown]
# ## Day 4 Observations
#
# ## Day 4 Observation
#
# PPO training completed successfully without numerical instability.
# The learned policy converged to a conservative strategy that predominantly selects the Hold action.
#
# This behavior is consistent with the reward design, where transaction risk dominates expected profit due to noisy price dynamics.
#
# This confirms that the environment and reward function support stable learning.
